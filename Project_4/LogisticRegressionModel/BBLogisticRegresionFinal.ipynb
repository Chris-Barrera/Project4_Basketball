# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/BasketBallRevised - basketball_cleaned_final.csv')
df.head()
# Out:
#              Player  YearsInLeague  GamesPlayed  MinutesPlayed  FieldGoal  \
# 0      Keith Askins              9          486           7983        677
# 1  Charles Barkley*             16         1073          39330       8435
# 2      Eric Bledsoe              7          380          10039       1657
# 3       Tom Boswell              6          366           7046       1096
# 4      Jason Caffey              8          462           9045       1276
#
#    FieldGoalAttempt  3PointsMade  3PointAttempts  FreeThrow  \
# 0              1688          275             774        223
# 1             15605          538            2020       6349
# 2              3709          294             890       1042
# 3              2058            6              11        623
# 4              2652            0               8        816
#
#    FreeThrowAttempts  ...  FieldGoal%  3Pointer%  FreeThrow%  \
# 0                311  ...       0.401      0.355       0.717
# ...

# %%
df = df.drop(columns=['Player', 'BirthDate', 'BirthCity', 'BirthState'])

# %%
#np.where(condition, value if condition is true, value if condition is false)
#df['hasimage'] = np.where(df['photos']!= '[]', True, False)
df['AboveAvg'] = np.where(df['Points'] > 3953.236994
, 1, 0)

# %%
y = df['AboveAvg'].ravel()
y[:5]
# Out:
# array([0, 1, 1, 0, 0])

# %%
X = df.copy()
X = X.drop(columns=['AboveAvg', 'Points'])
X.head()
# Out:
#    YearsInLeague  GamesPlayed  MinutesPlayed  FieldGoal  FieldGoalAttempt  \
# 0              9          486           7983        677              1688
# 1             16         1073          39330       8435             15605
# 2              7          380          10039       1657              3709
# 3              6          366           7046       1096              2058
# 4              8          462           9045       1276              2652
#
#    3PointsMade  3PointAttempts  FreeThrow  FreeThrowAttempts  OffesiveRebound  \
# 0          275             774        223                311              525
# 1          538            2020       6349               8643             4260
# 2          294             890       1042               1325              310
# 3            6              11        623                860              676
# 4            0               8        816               1282              841
#
# ...

# %%
from scipy import stats

x = df['FieldGoalAttempt']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FieldGoalAttempt')
plt.ylabel('Points')
plt.title('FieldGoalAttempt')
plt.show()

# %%
x = df['FieldGoal']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FieldGoal')
plt.ylabel('Points')
plt.title('FieldGoal')
plt.show()

# %%
x = df['FreeThrow']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FreeThrow')
plt.ylabel('Points')
plt.title('FreeThrow')
plt.show()

# %%
x = df['FreeThrowAttempts']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FreeThrowAttempts')
plt.ylabel('Points')
plt.title('FreeThrowAttempts')
plt.show()

# %%
x = df['MinutesPlayed']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('MinutesPlayed')
plt.ylabel('Points')
plt.title('MinutesPlayed')
plt.show()

# %%
x = df['3Pointer%']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('3Pointer%')
plt.ylabel('Points')
plt.title('3Pointer%')
plt.show()

# %%
x = df['AssitPerGame']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('AssitPerGame')
plt.ylabel('Points')
plt.title('AssitPerGame')
plt.show()

# %%
x = df['FieldGoal%']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FieldGoal%')
plt.ylabel('Points')
plt.title('FieldGoal%')
plt.show()

# %%
x = df['TotalReboundsPerGames']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('TotalReboundPerGames')
plt.ylabel('Points')
plt.title('TotalReboundPerGames')
plt.show()

# %%
x = df['FreeThrow%']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FreeThrow%')
plt.ylabel('Points')
plt.title('FreeThrow%')
plt.show()

# %%
y = df['AboveAvg'].ravel()
y[:5]
# Out:
# array([0, 1, 1, 0, 0])

# %%
from sklearn.model_selection import train_test_split
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
from sklearn.preprocessing import StandardScaler
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.9952550415183867
# Testing Data Score: 0.9928952042628775

# %%
predictions = classifier.predict(X_test_scaled)
results = pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
results.head(5)
# Out:
#    Prediction  Actual
# 0           0       0
# 1           0       0
# 2           1       1
# 3           1       1
# 4           0       0

# %%
from sklearn.metrics import accuracy_score
# Display the accuracy score for the test dataset.
accuracy_score(y_test, predictions)
# Out:
# 0.9928952042628775
