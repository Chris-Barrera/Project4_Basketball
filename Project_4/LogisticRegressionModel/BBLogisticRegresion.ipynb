# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/BasketBallRevised - basketball_cleaned (1).csv')
df.head()
# Out:
#              Player  YearsInLeague  GamesPlayed  MinutesPlayed  FieldGoal  \
# 0      Keith Askins              9          486           7983        677
# 1  Charles Barkley*             16         1073          39330       8435
# 2      Eric Bledsoe              7          380          10039       1657
# 3       Tom Boswell              6          366           7046       1096
# 4      Jason Caffey              8          462           9045       1276
#
#    FieldGoalAttempt  3PointsMade  3PointAttempts  FreeThrow  \
# 0              1688          275             774        223
# 1             15605          538            2020       6349
# 2              3709          294             890       1042
# 3              2058            6              11        623
# 4              2652            0               8        816
#
#    FreeThrowAttempts  ...  FieldGoal%  3Pointer%  FreeTthrow%  \
# 0                311  ...       0.401      0.355        0.717
# 1               8643  ...       0.541      0.266        0.735
# 2               1325  ...       0.447      0.330        0.786
# 3                860  ...       0.533      0.545        0.724
# 4               1282  ...       0.481      0.000        0.637
#
#    MinutesPlayedPerGame  MinutesPlayedPerGame.1  TotalReboundsPerGames  \
# 0                  16.4                     3.8                    2.9
# 1                  36.7                    22.1                   11.7
# 2                  26.4                    12.2                    3.7
# 3                  19.3                     7.7                    4.7
# 4                  19.6                     7.3                    4.4
#
#    AssitPerGame     BirthDate   BirthCity  BirthState
# 0           0.8  Dec 15, 1967      Athens     Alabama
# 1           3.9  Feb 20, 1963       Leeds     Alabama
# 2           4.4   Dec 9, 1989  Birmingham     Alabama
# 3           1.6   Oct 2, 1953  Montgomery     Alabama
# 4           0.9  Jun 12, 1973      Mobile     Alabama
#
# [5 rows x 28 columns]

# %%
df = df.drop(columns=['Player', 'BirthDate', 'BirthCity', 'BirthState'])

# %%
#np.where(condition, value if condition is true, value if condition is false)
#df['hasimage'] = np.where(df['photos']!= '[]', True, False)
df['AboveAvg'] = np.where(df['Points'] > 5791.000000
, 1, 0)

# %%
y = df['AboveAvg'].ravel()
y[:5]
# Out:
# array([0, 1, 0, 0, 0])

# %%
X = df.copy()
X = X.drop(columns=['AboveAvg', 'Points'])
X.head()
# Out:
#    YearsInLeague  GamesPlayed  MinutesPlayed  FieldGoal  FieldGoalAttempt  \
# 0              9          486           7983        677              1688
# 1             16         1073          39330       8435             15605
# 2              7          380          10039       1657              3709
# 3              6          366           7046       1096              2058
# 4              8          462           9045       1276              2652
#
#    3PointsMade  3PointAttempts  FreeThrow  FreeThrowAttempts  OffesiveRebound  \
# 0          275             774        223                311              525
# 1          538            2020       6349               8643             4260
# 2          294             890       1042               1325              310
# 3            6              11        623                860              676
# 4            0               8        816               1282              841
#
#    ...  Block  TurnOvers  PersonalFoul  FieldGoal%  3Pointer%  FreeTthrow%  \
# 0  ...    170        321          1094       0.401      0.355        0.717
# 1  ...    888       3376          3287       0.541      0.266        0.735
# 2  ...    184        990           740       0.447      0.330        0.786
# 3  ...    111        474          1102       0.533      0.545        0.724
# 4  ...    110        647          1148       0.481      0.000        0.637
#
#    MinutesPlayedPerGame  MinutesPlayedPerGame.1  TotalReboundsPerGames  \
# 0                  16.4                     3.8                    2.9
# 1                  36.7                    22.1                   11.7
# 2                  26.4                    12.2                    3.7
# 3                  19.3                     7.7                    4.7
# 4                  19.6                     7.3                    4.4
#
#    AssitPerGame
# 0           0.8
# 1           3.9
# 2           4.4
# 3           1.6
# 4           0.9
#
# [5 rows x 23 columns]

# %%
from scipy import stats

x = df['FieldGoalAttempt']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FieldGoalAttempt')
plt.ylabel('Points')
plt.title('FieldGoalAttempt')
plt.show()

# %%
x = df['FieldGoal']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FieldGoal')
plt.ylabel('Points')
plt.title('FieldGoal')
plt.show()

# %%
x = df['FreeThrow']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FreeThrow')
plt.ylabel('Points')
plt.title('FreeThrow')
plt.show()

# %%
x = df['FreeThrowAttempts']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('FreeThrowAttempts')
plt.ylabel('Points')
plt.title('FreeThrowAttempts')
plt.show()

# %%
x = df['TurnOvers']
y = df['Points']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel, color="red")
plt.xlabel('TurnOvers')
plt.ylabel('Points')
plt.title('TurnOvers')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9756820877817319
# Testing Data Score: 0.9786856127886323

# %%
predictions = classifier.predict(X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
results.head(10)
# Out:
#    Prediction  Actual
# 0           0       0
# 1           1       1
# 2           0       0
# 3           0       0
# 4           0       0
# 5           1       0
# 6           1       1
# 7           0       0
# 8           0       0
# 9           1       1

# %%
from sklearn.metrics import accuracy_score
# Display the accuracy score for the test dataset.
accuracy_score(y_test, predictions)
# Out:
# 0.9786856127886323

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-349611edaeca> in <cell line: 1>()
# ----> 1 sns.regplot(x=X, y=y, data=df);
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     745 ):
#     746
# --> 747     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     748                                  scatter, fit_reg, ci, n_boot, units, seed,
#     749                                  order, logistic, lowess, robust, logx,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     105
#     106         # Extract the data vals from the arguments or passed dataframe
# --> 107         self.establish_variables(data, x=x, y=y, units=units,
#     108                                  x_partial=x_partial, y_partial=y_partial)
#     109
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in establish_variables(self, data, **kws)
#      51             if np.ndim(vector) > 1:
#      52                 err = "regplot inputs must be 1d"
# ---> 53                 raise ValueError(err)
#      54             setattr(self, var, vector)
#      55
#
# ValueError: regplot inputs must be 1d
